# %%
### Import all necessary modules
import numpy as np
# !pip install geopandas;
import geopandas as gpd
from shapely.geometry import shape

from bokeh.io import output_file, show,output_notebook
from bokeh.models import ColumnDataSource,ColorBar,HoverTool
from bokeh.transform import linear_cmap
from bokeh.plotting import figure
from bokeh.palettes import RdBu10

output_notebook()
# Out:
# Requirement already satisfied: geopandas in /Users/jthoma/opt/anaconda3/lib/python3.7/site-packages (0.8.1)
# Requirement already satisfied: pandas>=0.23.0 in /Users/jthoma/opt/anaconda3/lib/python3.7/site-packages (from geopandas) (1.0.1)
# Requirement already satisfied: pyproj>=2.2.0 in /Users/jthoma/opt/anaconda3/lib/python3.7/site-packages (from geopandas) (3.0.0.post1)
# Requirement already satisfied: fiona in /Users/jthoma/opt/anaconda3/lib/python3.7/site-packages (from geopandas) (1.8.17)
# Requirement already satisfied: shapely in /Users/jthoma/opt/anaconda3/lib/python3.7/site-packages (from geopandas) (1.7.1)
# Requirement already satisfied: numpy>=1.13.3 in /Users/jthoma/opt/anaconda3/lib/python3.7/site-packages (from pandas>=0.23.0->geopandas) (1.18.1)
# Requirement already satisfied: python-dateutil>=2.6.1 in /Users/jthoma/opt/anaconda3/lib/python3.7/site-packages (from pandas>=0.23.0->geopandas) (2.8.1)
# Requirement already satisfied: pytz>=2017.2 in /Users/jthoma/opt/anaconda3/lib/python3.7/site-packages (from pandas>=0.23.0->geopandas) (2019.3)
# Requirement already satisfied: certifi in /Users/jthoma/opt/anaconda3/lib/python3.7/site-packages (from pyproj>=2.2.0->geopandas) (2019.11.28)
# Requirement already satisfied: click-plugins>=1.0 in /Users/jthoma/opt/anaconda3/lib/python3.7/site-packages (from fiona->geopandas) (1.1.1)
# Requirement already satisfied: six>=1.7 in /Users/jthoma/opt/anaconda3/lib/python3.7/site-packages (from fiona->geopandas) (1.14.0)
# Requirement already satisfied: cligj>=0.5 in /Users/jthoma/opt/anaconda3/lib/python3.7/site-packages (from fiona->geopandas) (0.7.0)
# Requirement already satisfied: attrs>=17 in /Users/jthoma/opt/anaconda3/lib/python3.7/site-packages (from fiona->geopandas) (19.3.0)
# Requirement already satisfied: click<8,>=4.0 in /Users/jthoma/opt/anaconda3/lib/python3.7/site-packages (from fiona->geopandas) (7.0)
# Requirement already satisfied: munch in /Users/jthoma/opt/anaconda3/lib/python3.7/site-packages (from fiona->geopandas) (2.5.0)
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1001">Loading BokehJS ...</span>
#     </div>

# %%
### Read in shapefile with election data
us_election = gpd.read_file('US48_county_election_2016.shp')

### Create helper function that converts GeoDataFrame to bokeh format
def gpd_bokeh(df):
    """Convert geometries from geopandas to bokeh format"""
    nan = float('nan')
    lons = []
    lats = []
    for i,shape in enumerate(df.geometry.values):
        if shape.geom_type == 'MultiPolygon':
            gx = []
            gy = []
            ng = len(shape.geoms) - 1
            for j,member in enumerate(shape.geoms):
                xy = np.array(list(member.exterior.coords))
                xs = xy[:,0].tolist()
                ys = xy[:,1].tolist()
                gx.extend(xs)
                gy.extend(ys)
                if j < ng:
                    gx.append(nan)
                    gy.append(nan)
            lons.append(gx)
            lats.append(gy)

        else:     
            xy = np.array(list(shape.exterior.coords))
            xs = xy[:,0].tolist()
            ys = xy[:,1].tolist()
            lons.append(xs)
            lats.append(ys) 

    return lons,lats

# %%
### Create ColumnDataSource with county name, percent of the dem votes, and percent gop vote
lons, lats = gpd_bokeh(us_election)
source = ColumnDataSource(data=dict(
    	x=lons, 
    	y=lats,
        County = us_election['NAME'],
        Percent_Democrat = us_election['per_dem'],
        Percent_Republican = us_election['per_gop'],
        ))

# %%
### Create color map for final map that shows political lean of each county
color_mapper = linear_cmap(field_name='Percent_Republican', palette=RdBu10,
                           low=min(us_election['per_gop']),
                           high=max(us_election['per_gop']))
TOOLS = "pan,wheel_zoom,reset,hover,save"

# %%
### Create an interactive map that when hovered over shows county name, percent dem, and percent gop votes
map = figure(plot_width=1000, plot_height=600,title="US: 2016 Election", tools=TOOLS,)
map.patches('x', 'y', source=source, line_color="white", line_width=0.1, color=color_mapper)

map.select_one(HoverTool).tooltips = [
    ('County Name', '@County'),
    ('Percent Democrat', '@Percent_Democrat'),
    ('Percent Republican', '@Percent_Republican')
]

color_bar = ColorBar(color_mapper=color_mapper['transform'], width=16, location=(0,0))
map.add_layout(color_bar, 'right')

# %%
show(map)
output_file("2016election.html")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-2-0801fb6d0142> in <module>
# ----> 1 show(map)
#       2 output_file("2016election.html")
#
# ~/opt/anaconda3/lib/python3.7/site-packages/bokeh/io/showing.py in show(obj, browser, new, notebook_handle, notebook_url, **kw)
#     141     # in Tornado) just in order to show a non-server object
#     142     if is_application or callable(obj):
# --> 143         return run_notebook_hook(state.notebook_type, 'app', obj, state, notebook_url, **kw)
#     144
#     145     return _show_with_state(obj, state, browser, new, notebook_handle=notebook_handle)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/bokeh/io/notebook.py in run_notebook_hook(notebook_type, action, *args, **kw)
#     300     if _HOOKS[notebook_type][action] is None:
#     301         raise RuntimeError("notebook hook for %r did not install %r action" % notebook_type, action)
# --> 302     return _HOOKS[notebook_type][action](*args, **kw)
#     303
#     304 #-----------------------------------------------------------------------------
#
# ~/opt/anaconda3/lib/python3.7/site-packages/bokeh/io/notebook.py in show_app(app, state, notebook_url, port, **kw)
#     476         origin = _origin_url(notebook_url)
#     477
# --> 478     server = Server({"/": app}, io_loop=loop, port=port,  allow_websocket_origin=[origin], **kw)
#     479
#     480     server_id = uuid4().hex
#
# ~/opt/anaconda3/lib/python3.7/site-packages/bokeh/server/server.py in __init__(self, applications, io_loop, http_server_kwargs, **kwargs)
#     356         for k, v in list(applications.items()):
#     357             if callable(v):
# --> 358                 applications[k] = Application(FunctionHandler(v))
#     359             if all(not isinstance(handler, DocumentLifecycleHandler)
#     360                    for handler in applications[k]._handlers):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/bokeh/application/handlers/function.py in __init__(self, func)
#     106         super(FunctionHandler, self).__init__()
#     107
# --> 108         _check_callback(func, ('doc',))
#     109
#     110         self._func = func
#
# ~/opt/anaconda3/lib/python3.7/site-packages/bokeh/util/callback_manager.py in _check_callback(callback, fargs, what)
#     178 def _check_callback(callback, fargs, what="Callback functions"):
#     179     '''Bokeh-internal function to check callback signature'''
# --> 180     sig = signature(callback)
#     181     formatted_args = format_signature(sig)
#     182     error_msg = what + " must have signature func(%s), got func%s"
#
# ~/opt/anaconda3/lib/python3.7/inspect.py in signature(obj, follow_wrapped)
#    3081 def signature(obj, *, follow_wrapped=True):
#    3082     """Get a signature object for the passed callable."""
# -> 3083     return Signature.from_callable(obj, follow_wrapped=follow_wrapped)
#    3084
#    3085
#
# ~/opt/anaconda3/lib/python3.7/inspect.py in from_callable(cls, obj, follow_wrapped)
#    2831         """Constructs Signature for the given callable object."""
#    2832         return _signature_from_callable(obj, sigcls=cls,
# -> 2833                                         follow_wrapper_chains=follow_wrapped)
#    2834
#    2835     @property
#
# ~/opt/anaconda3/lib/python3.7/inspect.py in _signature_from_callable(obj, follow_wrapper_chains, skip_bound_arg, sigcls)
#    2362                 else:
#    2363                     raise ValueError(
# -> 2364                         'no signature found for builtin type {!r}'.format(obj))
#    2365
#    2366     elif not isinstance(obj, _NonUserDefinedCallables):
#
# ValueError: no signature found for builtin type <class 'map'>
